# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_data.csv")

# %%
df.head()
# Out:
#        Patient Name   Age  Gender      Condition     Medication  Visit Date  \
# 0        David Lee   25.0   Other  Heart Disease      METFORMIN  2020-01-15
# 1      Emily Davis   40.0    Male       Diabetes  No_Medication  2018-04-05
# 2   Laura Martinez   35.0   Other         Asthma      METFORMIN  2019-12-01
# 3   Michael Wilson   40.0    Male       Diabetes      ALBUTEROL  2020-01-15
# 4        David Lee   40.0  Female         Asthma  No_Medication  2020-02-20
#
#   Blood Pressure  Cholesterol               Email  Phone Number  systolic  \
# 0         140/90        200.0   name@hospital.org  555-555-5555     140.0
# 1         120/80        200.0             Unknown       Unknown     120.0
# 2         110/70        160.0  contact@domain.com       Unknown     110.0
# 3         110/70        180.0   name@hospital.org  555-555-5555     110.0
# 4         110/70        180.0             Unknown                   110.0
#
#    diastolic
# 0       90.0
# 1       80.0
# 2       70.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient Name    1000 non-null   object
#  1   Age             1000 non-null   float64
#  2   Gender          1000 non-null   object
#  3   Condition       794 non-null    object
#  4   Medication      1000 non-null   object
#  5   Visit Date      1000 non-null   object
#  6   Blood Pressure  1000 non-null   object
#  7   Cholesterol     1000 non-null   float64
#  8   Email           1000 non-null   object
#  9   Phone Number    1000 non-null   object
#  10  systolic        1000 non-null   float64
#  11  diastolic       1000 non-null   float64
# dtypes: float64(4), object(8)
# memory usage: 93.9+ KB
